# %% [markdown]
# <a href="https://colab.research.google.com/github/pavansai26/learning-rate-theory/blob/master/LEARNING_RATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **what is learning rate**?

# %% [markdown]
# # **why we call learning rate ?**

# %% [markdown]
# # **what should be the desirable learning rate ?**

# %% [markdown]
# # **small learning rate**

# %% [markdown]
# # **what is small learning rate ?**

# %% [markdown]
# # **what is the problem with the small learning rate?**

# %% [markdown]
# # **![image.png](data:image/png;base64,...)**

# %% [markdown]
# # **big learning rate?**

# %% [markdown]
# # **what is big learning rate?**

# %% [markdown]
# # **what is the problem with the big learning rate?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **best learning rate**

# %% [markdown]
# # **what is best learning rate?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
